# %%
# !mkdir deeplab
# %cd deeplab
# Out:
# /content/deeplab

# %%
# !pip install tensorflow-gpu==1.15.3
# !pip install tf_slim==1.0.0
# Out:
# ...
#      |████████████████████████████████| 411.0MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 46.1MB/s
# ...
#      |████████████████████████████████| 51kB 7.6MB/s
# ...
#      |████████████████████████████████| 512kB 48.5MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=058f32feef5dae9fb0434e16938d5edfe26eae103f54314a9883a2237f908551
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.3.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorflow-estimator<2.4.0,>=2.3.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...

# %%
# !pip install tf_slim

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone --depth 1 https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 2250, done.
# remote: Counting objects: 100% (2250/2250), done.
# remote: Compressing objects: 100% (1947/1947), done.
# remote: Total 2250 (delta 550), reused 948 (delta 277), pack-reused 0
# Receiving objects: 100% (2250/2250), 30.51 MiB | 26.61 MiB/s, done.
# Resolving deltas: 100% (550/550), done.

# %%
# %cd models/research/deeplab/datasets
# Out:
# /content/models/research/deeplab/datasets

# %%
# !mkdir pascal_voc_seg

# %%
# !gdown https://drive.google.com/uc?id=1rATNHizJdVHnaJtt-hW9MOgjxoaajzdh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rATNHizJdVHnaJtt-hW9MOgjxoaajzdh
# To: /content/models/research/deeplab/datasets/VOCtrainval_11-May-2012.tar
# 2.00GB [00:38, 52.6MB/s]

# %%
# !mv VOCtrainval_11-May-2012.tar pascal_voc_seg/

# %%
! sed -i -e "s/python .\/remove_gt_colormap.py/python3 .\/remove_gt_colormap.py/g" -i -e "s/python .\/build_voc2012_data.py/python3 .\/build_voc2012_data.py/g" download_and_convert_voc2012.sh

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pwd
# Out:
# /content/models/research/deeplab/datasets

# %%
# !sh download_and_convert_voc2012.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004172.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004175.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004212.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004259.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004279.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004321.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004339.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004345.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004358.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004363.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004365.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004367.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004396.png
#   inflating: voc2012/VOC2012/SegmentationClass/2008_004399.png
# ...

# %%
# %cd ../..
# Out:
# /content/models/research

# %%
# !mkdir -p deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train
# !mkdir -p deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/eval

# %%
# !mkdir -p deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/vis

# %%
# %env PATH_TO_TRAIN_DIR=/content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train

# %env PATH_TO_DATASET=/content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/tfrecord
# %env PYTHONPATH=/content/deeplab/models/research:/content/deeplab/models/research/deeplab:/content/deeplab/models/research/slim:/env/python
# Out:
# env: PATH_TO_TRAIN_DIR=/content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train
# env: PATH_TO_DATASET=/content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/tfrecord
# env: PYTHONPATH=/content/deeplab/models/research:/content/deeplab/models/research/deeplab:/content/deeplab/models/research/slim:/env/python

# %%
# !python3 deeplab/train.py \
    --logtostderr \
    --training_number_of_steps=5000 \
    --train_split="train" \
    --model_variant="mobilenet_v3_small_seg" \
    --decoder_output_stride=16 \
    --train_crop_size="513,513" \
    --train_batch_size=8 \
    --dataset="pascal_voc_seg" \
    --save_interval_secs=300 \
    --save_summaries_secs=300 \
    --save_summaries_images=True \
    --log_steps=100 \
    --train_logdir=${PATH_TO_TRAIN_DIR} \
    --dataset_dir=${PATH_TO_DATASET}
# Out:
# Traceback (most recent call last):
#   File "deeplab/train.py", line 28, in <module>
#     from deeplab import common
# ModuleNotFoundError: No module named 'deeplab'

# %%
# !zip -r /content/deeplab_checkpoints.zip ${PATH_TO_TRAIN_DIR}
from google.colab import files
files.download("/content/deeplab_checkpoints.zip")
# Out:
# 	zip warning: name not matched: /content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train
#
# zip error: Nothing to do! (try: zip -r /content/deeplab_checkpoints.zip . -i /content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-8f9c2a757b41> in <module>()
#       1 get_ipython().system('zip -r /content/deeplab_checkpoints.zip ${PATH_TO_TRAIN_DIR}')
#       2 from google.colab import files
# ----> 3 files.download("/content/deeplab_checkpoints.zip")
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     141       raise OSError(msg)
#     142     else:
# --> 143       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     144
# ...

# %%
# Exporting model to frozen Graph to use in tensorflow js
! mkdir /content/deeplab/saved_model/deeplabv3_mnv2_pascal_trainval/

# %%
# !pwd

# %%
! python deeplab/export_model.py \
--model_variant="mobilenet_v3_small_seg" \
--crop_size=257 \
--crop_size=257 \
--checkpoint_path=/content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train/model.ckpt-5000 \
--export_path=/content/deeplab/saved_model/deeplabv3_mnv2_pascal_trainval/frozen_inference_graph.pb

# %%
files.download("/content/deeplab/saved_model/deeplabv3_mnv2_pascal_trainval/frozen_inference_graph.pb")

# %%
# TensorBoard using de LOG_DIR
# %load_ext tensorboard
# %tensorboard \
  --logdir /content/deeplab/models/research/deeplab/datasets/pascal_voc_seg/exp/train_on_train_set/train

# %%
#
